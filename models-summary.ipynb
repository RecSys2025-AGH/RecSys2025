# %% [markdown]
# # Synerise's baseline

# %% [markdown]
# ![{8AFCB582-9AB6-43EE-8655-5C92F47EB1DC}.png](attachment:{8AFCB582-9AB6-43EE-8655-5C92F47EB1DC}.png)

# %% [markdown]
# ![{BE589347-5410-4A27-82F9-1A0E23848CE9}.png](attachment:{BE589347-5410-4A27-82F9-1A0E23848CE9}.png)

# %% [markdown]
# ![{A3BFC97C-5B40-4866-9E7D-CD2894F893F9}.png](attachment:{A3BFC97C-5B40-4866-9E7D-CD2894F893F9}.png)

# %% [markdown]
# First run on our data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
