# %%
import numpy as np
import polars as pl

# %% [markdown]
# # Data exploration for RecSys 2025
#
# For the purpose of the efficiency and processing multiple datasets with millions of rows, we decided to use **Polars** instead of Pandas, because of its Lazy API, which enables us to better manage memory.

# %%
data_folder = "../data"

data = {
    "add_to_cart": pl.scan_parquet(f"{data_folder}/add_to_cart.parquet", try_parse_hive_dates=True),
    "page_visit": pl.scan_parquet(f"{data_folder}/page_visit.parquet"),
    "product_buy": pl.scan_parquet(f"{data_folder}/product_buy.parquet"),
    "product_properties": pl.scan_parquet(f"{data_folder}/product_properties.parquet"),
    "remove_from_cart": pl.scan_parquet(f"{data_folder}/remove_from_cart.parquet"),
    "search_query": pl.scan_parquet(f"{data_folder}/search_query.parquet"),
}

inputs = {
    "relevant_clients": np.load(f"{data_folder}/input/relevant_clients.npy", mmap_mode="r")
}

targets = {
    "active_clients": np.load(f"{data_folder}/target/active_clients.npy", mmap_mode="r"),
    "popularity_propensity_category": np.load(f"{data_folder}/target/popularity_propensity_category.npy", mmap_mode="r"),
    "popularity_propensity_sku": np.load(f"{data_folder}/target/popularity_propensity_sku.npy", mmap_mode="r"),
    "propensity_category": np.load(f"{data_folder}/target/propensity_category.npy", mmap_mode="r"),
    "propensity_sku": np.load(f"{data_folder}/target/propensity_sku.npy", mmap_mode="r"),
}

# %%
for df in data:
    print(f"{df}:")
    print(data[df].head())
    print(data[df].describe())
# Out:
# add_to_cart:
# naive plan: (run LazyFrame.explain(optimized=True) to see the optimized plan)
#
# SLICE[offset: 0, len: 5]
#   Parquet SCAN [../data/add_to_cart.parquet]
#   PROJECT */3 COLUMNS
# shape: (9, 4)
# ┌────────────┬─────────────┬─────────────────────┬───────────────┐
# │ statistic  ┆ client_id   ┆ timestamp           ┆ sku           │
# │ ---        ┆ ---         ┆ ---                 ┆ ---           │
# │ str        ┆ f64         ┆ str                 ┆ f64           │
# ╞════════════╪═════════════╪═════════════════════╪═══════════════╡
# │ count      ┆ 5.235882e6  ┆ 5235882             ┆ 5.235882e6    │
# │ null_count ┆ 0.0         ┆ 0                   ┆ 0.0           │
# │ mean       ┆ 1.1941e7    ┆ null                ┆ 748255.043147 │
# │ std        ┆ 6.8914e6    ┆ null                ┆ 433663.464805 │
# │ min        ┆ 5.0         ┆ 2022-05-23 00:10:15 ┆ 0.0           │
# │ 25%        ┆ 5.964675e6  ┆ null                ┆ 370909.0      │
# │ 50%        ┆ 1.194213e7  ┆ null                ┆ 748335.0      │
# │ 75%        ┆ 1.790411e7  ┆ null                ┆ 1.12609e6     │
# │ max        ┆ 2.3875211e7 ┆ 2022-10-10 23:59:10 ┆ 1.495777e6    │
# └────────────┴─────────────┴─────────────────────┴───────────────┘
# page_visit:
# naive plan: (run LazyFrame.explain(optimized=True) to see the optimized plan)
#
# SLICE[offset: 0, len: 5]
#   Parquet SCAN [../data/page_visit.parquet]
#   PROJECT */3 COLUMNS
# shape: (9, 4)
# ┌────────────┬──────────────┬─────────────────────┬──────────────┐
# │ statistic  ┆ client_id    ┆ timestamp           ┆ url          │
# │ ---        ┆ ---          ┆ ---                 ┆ ---          │
# │ str        ┆ f64          ┆ str                 ┆ f64          │
# ╞════════════╪══════════════╪═════════════════════╪══════════════╡
# │ count      ┆ 1.50713186e8 ┆ 150713186           ┆ 1.50713186e8 │
# │ null_count ┆ 0.0          ┆ 0                   ┆ 0.0          │
# │ mean       ┆ 1.1948e7     ┆ null                ┆ 7.6525e6     │
# │ std        ┆ 6.8910e6     ┆ null                ┆ 4.4715e6     │
# │ min        ┆ 0.0          ┆ 2022-05-23 00:10:00 ┆ 1.0          │
# │ 25%        ┆ 5.979531e6   ┆ null                ┆ 3.462826e6   │
# │ 50%        ┆ 1.1949388e7  ┆ null                ┆ 7.797117e6   │
# │ 75%        ┆ 1.7918985e7  ┆ null                ┆ 1.1157244e7  │
# │ max        ┆ 2.3875259e7  ┆ 2022-10-10 23:59:59 ┆ 1.5869648e7  │
# └────────────┴──────────────┴─────────────────────┴──────────────┘
# product_buy:
# naive plan: (run LazyFrame.explain(optimized=True) to see the optimized plan)
#
# SLICE[offset: 0, len: 5]
#   Parquet SCAN [../data/product_buy.parquet]
#   PROJECT */3 COLUMNS
# shape: (9, 4)
# ┌────────────┬─────────────┬─────────────────────┬───────────────┐
# │ statistic  ┆ client_id   ┆ timestamp           ┆ sku           │
# │ ---        ┆ ---         ┆ ---                 ┆ ---           │
# │ str        ┆ f64         ┆ str                 ┆ f64           │
# ╞════════════╪═════════════╪═════════════════════╪═══════════════╡
# │ count      ┆ 1.682296e6  ┆ 1682296             ┆ 1.682296e6    │
# │ null_count ┆ 0.0         ┆ 0                   ┆ 0.0           │
# │ mean       ┆ 1.1941e7    ┆ null                ┆ 746549.671699 │
# │ std        ┆ 6.8918e6    ┆ null                ┆ 433618.826745 │
# │ min        ┆ 14.0        ┆ 2022-05-23 00:10:40 ┆ 4.0           │
# │ 25%        ┆ 5.964836e6  ┆ null                ┆ 369890.0      │
# │ 50%        ┆ 1.1924383e7 ┆ null                ┆ 745837.0      │
# │ 75%        ┆ 1.791873e7  ┆ null                ┆ 1.121913e6    │
# │ max        ┆ 2.3875234e7 ┆ 2022-10-10 23:59:25 ┆ 1.495777e6    │
# └────────────┴─────────────┴─────────────────────┴───────────────┘
# product_properties:
# naive plan: (run LazyFrame.explain(optimized=True) to see the optimized plan)
#
# SLICE[offset: 0, len: 5]
#   Parquet SCAN [../data/product_properties.parquet]
#   PROJECT */4 COLUMNS
# shape: (9, 5)
# ┌────────────┬───────────────┬─────────────┬────────────┬─────────────────────────────────┐
# │ statistic  ┆ sku           ┆ category    ┆ price      ┆ name                            │
# │ ---        ┆ ---           ┆ ---         ┆ ---        ┆ ---                             │
# │ str        ┆ f64           ┆ f64         ┆ f64        ┆ str                             │
# ╞════════════╪═══════════════╪═════════════╪════════════╪═════════════════════════════════╡
# │ count      ┆ 1.197634e6    ┆ 1.197634e6  ┆ 1.197634e6 ┆ 1197634                         │
# │ null_count ┆ 0.0           ┆ 0.0         ┆ 0.0        ┆ 0                               │
# │ mean       ┆ 748283.428842 ┆ 3497.911358 ┆ 47.466395  ┆ null                            │
# │ std        ┆ 431765.419146 ┆ 1908.822438 ┆ 27.894335  ┆ null                            │
# │ min        ┆ 0.0           ┆ 0.0         ┆ 0.0        ┆ [  0   0  28 150  36  36   4  … │
# │ 25%        ┆ 374395.0      ┆ 1902.0      ┆ 24.0       ┆ null                            │
# │ 50%        ┆ 748439.0      ┆ 3378.0      ┆ 45.0       ┆ null                            │
# │ 75%        ┆ 1.12245e6     ┆ 5131.0      ┆ 71.0       ┆ null                            │
# │ max        ┆ 1.495777e6    ┆ 6918.0      ┆ 99.0       ┆ [99 76 14 39 39 96 73 96 39 39… │
# └────────────┴───────────────┴─────────────┴────────────┴─────────────────────────────────┘
# remove_from_cart:
# naive plan: (run LazyFrame.explain(optimized=True) to see the optimized plan)
#
# SLICE[offset: 0, len: 5]
#   Parquet SCAN [../data/remove_from_cart.parquet]
#   PROJECT */3 COLUMNS
# shape: (9, 4)
# ┌────────────┬─────────────┬─────────────────────┬───────────────┐
# │ statistic  ┆ client_id   ┆ timestamp           ┆ sku           │
# │ ---        ┆ ---         ┆ ---                 ┆ ---           │
# │ str        ┆ f64         ┆ str                 ┆ f64           │
# ╞════════════╪═════════════╪═════════════════════╪═══════════════╡
# │ count      ┆ 1.697891e6  ┆ 1697891             ┆ 1.697891e6    │
# │ null_count ┆ 0.0         ┆ 0                   ┆ 0.0           │
# │ mean       ┆ 1.1937e7    ┆ null                ┆ 748744.345105 │
# │ std        ┆ 6.8876e6    ┆ null                ┆ 433282.909407 │
# │ min        ┆ 125.0       ┆ 2022-05-23 00:11:00 ┆ 0.0           │
# │ 25%        ┆ 5.952338e6  ┆ null                ┆ 371784.0      │
# │ 50%        ┆ 1.1944942e7 ┆ null                ┆ 749039.0      │
# │ 75%        ┆ 1.7879097e7 ┆ null                ┆ 1.126615e6    │
# │ max        ┆ 2.3875093e7 ┆ 2022-10-10 23:59:55 ┆ 1.495777e6    │
# └────────────┴─────────────┴─────────────────────┴───────────────┘
# search_query:
# naive plan: (run LazyFrame.explain(optimized=True) to see the optimized plan)
#
# SLICE[offset: 0, len: 5]
#   Parquet SCAN [../data/search_query.parquet]
#   PROJECT */3 COLUMNS
# shape: (9, 4)
# ┌────────────┬─────────────┬─────────────────────┬─────────────────────────────────┐
# │ statistic  ┆ client_id   ┆ timestamp           ┆ query                           │
# │ ---        ┆ ---         ┆ ---                 ┆ ---                             │
# │ str        ┆ f64         ┆ str                 ┆ str                             │
# ╞════════════╪═════════════╪═════════════════════╪═════════════════════════════════╡
# │ count      ┆ 9.571258e6  ┆ 9571258             ┆ 9571258                         │
# │ null_count ┆ 0.0         ┆ 0                   ┆ 0                               │
# │ mean       ┆ 1.1958e7    ┆ null                ┆ null                            │
# │ std        ┆ 6.8918e6    ┆ null                ┆ null                            │
# │ min        ┆ 36.0        ┆ 2022-05-23 13:13:20 ┆ [  0   0  33 170 130  74   4 2… │
# │ 25%        ┆ 5.988854e6  ┆ null                ┆ null                            │
# │ 50%        ┆ 1.1973021e7 ┆ null                ┆ null                            │
# │ 75%        ┆ 1.7917417e7 ┆ null                ┆ null                            │
# │ max        ┆ 2.3875194e7 ┆ 2022-10-10 23:59:30 ┆ [99 99 99 99 99 99 99 73 99 99… │
# └────────────┴─────────────┴─────────────────────┴─────────────────────────────────┘

# %%
clients = pl.concat([data[df].select("client_id") for df in data if df != "product_properties"])
unique_clients = clients.select(pl.col("client_id").n_unique()).collect().item()
print(f"Unique clients: {unique_clients}")
# Out:
# Unique clients: 18889063

# %%
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.0 (20241103.1931)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="1397pt" height="337pt"
#  viewBox="0.00 0.00 1397.00 337.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 333)">
# <title>polars_query</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-333 1393,-333 1393,4 -4,4"/>
# <!-- p1 -->
# <g id="node1" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="694.62,-329 640.62,-329 640.62,-293 694.62,-293 694.62,-329"/>
# <text text-anchor="middle" x="667.62" y="-305.95" font-family="Times New Roman,serif" font-size="14.00">π 1/1</text>
# </g>
# <!-- p2 -->
# <g id="node2" class="node">
# <title>p2</title>
# <polygon fill="none" stroke="black" points="706.38,-257 628.88,-257 628.88,-221 706.38,-221 706.38,-257"/>
# <text text-anchor="middle" x="667.62" y="-233.95" font-family="Times New Roman,serif" font-size="14.00">DISTINCT</text>
# </g>
# <!-- p1&#45;&#45;p2 -->
# <g id="edge1" class="edge">
# <title>p1&#45;&#45;p2</title>
# <path fill="none" stroke="black" d="M667.62,-292.7C667.62,-281.85 667.62,-267.92 667.62,-257.1"/>
# </g>
# <!-- p3 -->
# <g id="node3" class="node">
# <title>p3</title>
# <polygon fill="none" stroke="black" points="697.38,-185 637.88,-185 637.88,-149 697.38,-149 697.38,-185"/>
# <text text-anchor="middle" x="667.62" y="-161.95" font-family="Times New Roman,serif" font-size="14.00">UNION</text>
# </g>
# <!-- p2&#45;&#45;p3 -->
# <g id="edge2" class="edge">
# <title>p2&#45;&#45;p3</title>
# <path fill="none" stroke="black" d="M667.62,-220.7C667.62,-209.85 667.62,-195.92 667.62,-185.1"/>
# </g>
# <!-- p4 -->
# <g id="node4" class="node">
# <title>p4</title>
# <polygon fill="none" stroke="black" points="252.62,-113 198.62,-113 198.62,-77 252.62,-77 252.62,-113"/>
# <text text-anchor="middle" x="225.62" y="-89.95" font-family="Times New Roman,serif" font-size="14.00">π 1/1</text>
# </g>
# <!-- p3&#45;&#45;p4 -->
# <g id="edge3" class="edge">
# <title>p3&#45;&#45;p4</title>
# <path fill="none" stroke="black" d="M637.59,-161.24C556.08,-148.33 331.58,-112.78 253.12,-100.36"/>
# </g>
# <!-- p6 -->
# <g id="node6" class="node">
# <title>p6</title>
# <polygon fill="none" stroke="black" points="522.62,-113 468.62,-113 468.62,-77 522.62,-77 522.62,-113"/>
# <text text-anchor="middle" x="495.62" y="-89.95" font-family="Times New Roman,serif" font-size="14.00">π 1/1</text>
# </g>
# <!-- p3&#45;&#45;p6 -->
# <g id="edge5" class="edge">
# <title>p3&#45;&#45;p6</title>
# <path fill="none" stroke="black" d="M637.66,-153.81C605.33,-140.65 554.26,-119.86 522.97,-107.13"/>
# </g>
# <!-- p8 -->
# <g id="node8" class="node">
# <title>p8</title>
# <polygon fill="none" stroke="black" points="694.62,-113 640.62,-113 640.62,-77 694.62,-77 694.62,-113"/>
# <text text-anchor="middle" x="667.62" y="-89.95" font-family="Times New Roman,serif" font-size="14.00">π 1/1</text>
# </g>
# <!-- p3&#45;&#45;p8 -->
# <g id="edge7" class="edge">
# <title>p3&#45;&#45;p8</title>
# <path fill="none" stroke="black" d="M667.62,-148.7C667.62,-137.85 667.62,-123.92 667.62,-113.1"/>
# </g>
# <!-- p10 -->
# <g id="node10" class="node">
# <title>p10</title>
# <polygon fill="none" stroke="black" points="877.62,-113 823.62,-113 823.62,-77 877.62,-77 877.62,-113"/>
# <text text-anchor="middle" x="850.62" y="-89.95" font-family="Times New Roman,serif" font-size="14.00">π 1/1</text>
# </g>
# <!-- p3&#45;&#45;p10 -->
# <g id="edge9" class="edge">
# <title>p3&#45;&#45;p10</title>
# <path fill="none" stroke="black" d="M697.84,-154.44C732.77,-141.08 789.73,-119.29 823.35,-106.43"/>
# </g>
# <!-- p12 -->
# <g id="node12" class="node">
# <title>p12</title>
# <polygon fill="none" stroke="black" points="1172.62,-113 1118.62,-113 1118.62,-77 1172.62,-77 1172.62,-113"/>
# <text text-anchor="middle" x="1145.62" y="-89.95" font-family="Times New Roman,serif" font-size="14.00">π 1/1</text>
# </g>
# <!-- p3&#45;&#45;p12 -->
# <g id="edge11" class="edge">
# <title>p3&#45;&#45;p12</title>
# <path fill="none" stroke="black" d="M697.53,-161.62C784.19,-148.93 1034.62,-112.26 1118.14,-100.02"/>
# </g>
# <!-- p5 -->
# <g id="node5" class="node">
# <title>p5</title>
# <polygon fill="none" stroke="black" points="255.25,-41 0,-41 0,0 255.25,0 255.25,-41"/>
# <text text-anchor="middle" x="127.62" y="-23.7" font-family="Times New Roman,serif" font-size="14.00">Parquet SCAN [../data/add_to_cart.parquet]</text>
# <text text-anchor="middle" x="127.62" y="-7.2" font-family="Times New Roman,serif" font-size="14.00">π */3;</text>
# </g>
# <!-- p4&#45;&#45;p5 -->
# <g id="edge4" class="edge">
# <title>p4&#45;&#45;p5</title>
# <path fill="none" stroke="black" d="M202.4,-76.82C188.02,-66.18 169.51,-52.49 154.5,-41.38"/>
# </g>
# <!-- p7 -->
# <g id="node7" class="node">
# <title>p7</title>
# <polygon fill="none" stroke="black" points="520.12,-41 273.12,-41 273.12,0 520.12,0 520.12,-41"/>
# <text text-anchor="middle" x="396.62" y="-23.7" font-family="Times New Roman,serif" font-size="14.00">Parquet SCAN [../data/page_visit.parquet]</text>
# <text text-anchor="middle" x="396.62" y="-7.2" font-family="Times New Roman,serif" font-size="14.00">π */3;</text>
# </g>
# <!-- p6&#45;&#45;p7 -->
# <g id="edge6" class="edge">
# <title>p6&#45;&#45;p7</title>
# <path fill="none" stroke="black" d="M471.91,-76.63C457.38,-65.99 438.74,-52.34 423.64,-41.28"/>
# </g>
# <!-- p9 -->
# <g id="node9" class="node">
# <title>p9</title>
# <polygon fill="none" stroke="black" points="797.12,-41 538.12,-41 538.12,0 797.12,0 797.12,-41"/>
# <text text-anchor="middle" x="667.62" y="-23.7" font-family="Times New Roman,serif" font-size="14.00">Parquet SCAN [../data/product_buy.parquet]</text>
# <text text-anchor="middle" x="667.62" y="-7.2" font-family="Times New Roman,serif" font-size="14.00">π */3;</text>
# </g>
# <!-- p8&#45;&#45;p9 -->
# <g id="edge8" class="edge">
# <title>p8&#45;&#45;p9</title>
# <path fill="none" stroke="black" d="M667.62,-76.82C667.62,-66.18 667.62,-52.49 667.62,-41.38"/>
# </g>
# <!-- p11 -->
# <g id="node11" class="node">
# <title>p11</title>
# <polygon fill="none" stroke="black" points="1108.38,-41 814.88,-41 814.88,0 1108.38,0 1108.38,-41"/>
# <text text-anchor="middle" x="961.62" y="-23.7" font-family="Times New Roman,serif" font-size="14.00">Parquet SCAN [../data/remove_from_cart.parquet]</text>
# <text text-anchor="middle" x="961.62" y="-7.2" font-family="Times New Roman,serif" font-size="14.00">π */3;</text>
# </g>
# <!-- p10&#45;&#45;p11 -->
# <g id="edge10" class="edge">
# <title>p10&#45;&#45;p11</title>
# <path fill="none" stroke="black" d="M877.21,-76.63C893.5,-65.99 914.41,-52.34 931.33,-41.28"/>
# </g>
# <!-- p13 -->
# <g id="node13" class="node">
# <title>p13</title>
# <polygon fill="none" stroke="black" points="1389,-41 1126.25,-41 1126.25,0 1389,0 1389,-41"/>
# <text text-anchor="middle" x="1257.62" y="-23.7" font-family="Times New Roman,serif" font-size="14.00">Parquet SCAN [../data/search_query.parquet]</text>
# <text text-anchor="middle" x="1257.62" y="-7.2" font-family="Times New Roman,serif" font-size="14.00">π */3;</text>
# </g>
# <!-- p12&#45;&#45;p13 -->
# <g id="edge12" class="edge">
# <title>p12&#45;&#45;p13</title>
# <path fill="none" stroke="black" d="M1172.45,-76.63C1188.89,-65.99 1209.98,-52.34 1227.06,-41.28"/>
# </g>
# </g>
# </svg>
